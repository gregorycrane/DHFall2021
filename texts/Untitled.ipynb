# %%
import polyglot
from polyglot.detect import Detector
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5cef6ebd2f68> in <module>
#       1 import polyglot
# ----> 2 from polyglot.detect import Detector
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/polyglot/detect/__init__.py in <module>
# ----> 1 from .base import Detector, Language
#       2
#       3 __all__ = ['Detector', 'Language']
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/polyglot/detect/base.py in <module>
#       9
#      10
# ---> 11 from icu import Locale
#      12 import pycld2 as cld2
#      13
#
# ImportError: cannot import name 'Locale' from 'icu' (/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/icu/__init__.py)

# %%
from polyglot.mapping import Embedding

embeddings = Embedding.load("/home/rmyeid/polyglot_data/embeddings2/en/embeddings_pkl.tar.bz2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-42d205186433> in <module>
#       1 from polyglot.mapping import Embedding
#       2
# ----> 3 embeddings = Embedding.load("/home/rmyeid/polyglot_data/embeddings2/en/embeddings_pkl.tar.bz2")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/polyglot/mapping/embeddings.py in load(fname)
#     296     """Load an embedding dump generated by `save`"""
#     297
# --> 298     content = _open(fname).read()
#     299     if PY2:
#     300       state = pickle.loads(content)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/polyglot/utils.py in _open(file_, mode)
#      19     _, ext = path.splitext(file_)
#      20     if ext in {'.bz2', '.gz'}:
# ---> 21       s = tarfile.open(file_)
#      22       return s.extractfile(s.next())
#      23     else:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1597                     saved_pos = fileobj.tell()
#    1598                 try:
# -> 1599                     return func(name, "r", fileobj, **kwargs)
#    1600                 except (ReadError, CompressionError):
#    1601                     if fileobj is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1662
#    1663         try:
# -> 1664             fileobj = gzip.GzipFile(name, mode + "b", compresslevel, fileobj)
#    1665         except OSError:
#    1666             if fileobj is not None and mode == 'r':
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/rmyeid/polyglot_data/embeddings2/en/embeddings_pkl.tar.bz2'
