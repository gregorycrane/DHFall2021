# %%
# Python program to convert Roman Numerals
# to Numbers

# This function returns value of each Roman symbol


def value(r):
	if (r == 'I'):
		return 1
	if (r == 'V'):
		return 5
	if (r == 'X'):
		return 10
	if (r == 'L'):
		return 50
	if (r == 'C'):
		return 100
	if (r == 'D'):
		return 500
	if (r == 'M'):
		return 1000
	return -1


def romanToDecimal(str):
	res = 0
	i = 0

	while (i < len(str)):

		# Getting value of symbol s[i]
		s1 = value(str[i])

		if (i + 1 < len(str)):

			# Getting value of symbol s[i + 1]
			s2 = value(str[i + 1])

			# Comparing both values
			if (s1 >= s2):

				# Value of current symbol is greater
				# or equal to the next symbol
				res = res + s1
				i = i + 1
			else:

				# Value of current symbol is greater
				# or equal to the next symbol
				res = res + s2 - s1
				i = i + 2
		else:
			res = res + s1
			i = i + 1

	return res


# Driver code
print("Integer form of Roman Numeral is"),
print(romanToDecimal("MCMIV"))
# Out:
# Integer form of Roman Numeral is
# 1904

# %%
import re

excepts = {}

rolename = 10
excepts['count'] = rolename
excepts['duke'] = rolename
excepts['emperor'] = rolename
excepts['east'] = 1
excepts['eastern'] = 1
excepts['ecclesiastical'] = 1
excepts['father'] = rolename
excepts['forum'] = 1
excepts['great'] = 1
excepts['holy'] = 1

excepts['innocent'] = 1 # as in the various popes named innocent
excepts['king'] = rolename
excepts['lower'] = 1
excepts['marquis'] = rolename
excepts['monophysite'] = 1
excepts['mount'] = 1
excepts['new'] = 1
excepts['north'] = 1
excepts['northern'] = 1
excepts['oriental'] = 1
excepts['pope'] = rolename
excepts['queen'] = rolename
excepts['south'] = 1
excepts['southern'] = 1
excepts['upper'] = 1
excepts['virgin'] = 1
excepts['west'] = 1
excepts['western'] = 1

lcasewords = {}
f = open('bury-all.xml')

# xml:id="ch40pa33se004
for l in f:
    if( not re.search('id="ch[0-9]+pa[0-9]+',l)):
        continue
    l = re.sub('<[^>]+>',' ',l)
    l = re.sub('[\;.;!?"\']',' ',l)
    wds = l.split()
    for foo in wds:
        if(re.search('^[a-z]',foo) and not foo in excepts):
            if( foo in lcasewords):
                lcasewords[foo] = 1 + lcasewords[foo]
            else:
                lcasewords[foo] = 1
   
f.close()

print('dictbuilt')
# Out:
# dictbuilt

# %%
smith2gibbon = {}

smith2gibbon['alaricus'] = 'alaric'
smith2gibbon['ambrosius'] = 'ambrose'
smith2gibbon['antiocheia'] = 'antioch'
smith2gibbon['arelate'] = 'arles'
smith2gibbon['athenae'] = 'athens'
smith2gibbon['augustodunum'] = 'autun'
smith2gibbon['aurelianus'] = 'aurelian'
smith2gibbon['bosporus'] = 'bosphorus'
smith2gibbon['burdigala'] = 'bordeaux'
smith2gibbon['cantacuzenus'] = 'cantacuzene'
smith2gibbon['carthago'] = 'carthage'
smith2gibbon['cassianus'] = 'cassian'
smith2gibbon['claudianus'] = 'claudian'
smith2gibbon['constantinopolis'] = 'constantinople'
smith2gibbon['corinthus'] = 'corinth'
smith2gibbon['cyprianus'] = 'cyprian'
smith2gibbon['cyrillus'] = 'cyril'
smith2gibbon['diocletianus'] = 'diocletian'
smith2gibbon['domitianus'] = 'domitian'
smith2gibbon['aegyptus'] = 'egypt'
smith2gibbon['gallia'] = 'gaul'
smith2gibbon['germania'] = 'germany'
smith2gibbon['gothi'] = 'goths'
smith2gibbon['gratianus'] = 'gratian'
smith2gibbon['gregorius'] = 'gregory'
smith2gibbon['homerus'] = 'homer'
smith2gibbon['nazianzenus'] = 'gregory nazianzen'
smith2gibbon['hadrianus'] = 'hadrian'
smith2gibbon['hellespontus'] = 'hellespont'
smith2gibbon['herodianus'] = 'herodian'
smith2gibbon['italia'] = 'italy'
smith2gibbon['justinus'] = 'justin'
smith2gibbon['julianus'] = 'julian'
smith2gibbon['laodiceia'] = 'laodicea'
smith2gibbon['londinium'] = 'london'
smith2gibbon['lugdunum'] = 'lyons'
smith2gibbon['massilia'] = 'marseille'
smith2gibbon['massilia'] = 'marseilles'
smith2gibbon['maximianus'] = 'maximian'
smith2gibbon['maximinus'] = 'maximin'
smith2gibbon['mediolanum'] = 'milan'
smith2gibbon['narbo'] = 'narbonne'
smith2gibbon['nemausus'] = 'nismes'
smith2gibbon['nicomedeia'] = 'nicomedea'
smith2gibbon['patavium'] = 'padua'
smith2gibbon['philadelpheia'] = 'philadelphia'
smith2gibbon['philippus'] = 'philip'
smith2gibbon['plinius'] = 'pliny'
smith2gibbon['porphyrius'] = 'porphyry'
smith2gibbon['lutetia'] = 'paris'
smith2gibbon['persis'] = 'persia'
smith2gibbon['plutarchus'] = 'plutarch'
smith2gibbon['rhodus'] = 'rhodes'
smith2gibbon['roma'] = 'rome'
smith2gibbon['selymbria'] = 'selybria'
smith2gibbon['theodoretus'] = 'theodoret'
smith2gibbon['theodorus'] = 'theodore'
smith2gibbon['theodoricus'] = 'theodoric'
smith2gibbon['tertullianus'] = 'tertullian'
smith2gibbon['theophylactus'] = 'theophylact'
smith2gibbon['tiberis'] = 'tiber'

smith2gibbon['trapezus'] = 'trebizond'
smith2gibbon['tolosa'] = 'tolouse'
smith2gibbon['trajanus'] = 'trajan'
smith2gibbon['augusta-trevirorum-geo'] = 'treves'
smith2gibbon['valentinianus'] = 'valentinian'
smith2gibbon['valerianus'] = 'valerian'

smith2gibbon['vandali'] = 'vandals'
smith2gibbon['vergilianus'] = 'virgil'
smith2gibbon['vienna'] = 'vienne'
smith2gibbon['eboracum'] = 'york'

smithnames = {}
f = open('smithnames.txt')
i = 0
for l in f:
    l = re.sub('\n','',l)
    args = l.split('\t')
    if( not len(args) == 5):
        continue
    smithnames[args[3]] = args[4]
    if( args[3] in smith2gibbon):
        smithnames[smith2gibbon[args[3]]] = args[4]
    if(i> 100):
        continue
    i = i + 1
    print(len(args),args[3],args[4])

smithnames['alps'] = 'alpes-geo'
smithnames['adriatic'] = 'adriaticum-mare-geo'
smithnames['amalfi'] = 'https://pleiades.stoa.org/places/432670'

smithnames['ammianus marcellinus'] = 'ammianus-marcellinus-bio-1'
smithnames['apamea'] = 'apameia-geo'
smithnames['apennine'] = 'apenninus-mons-geo'
smithnames['apennines'] = 'apenninus-mons-geo'
smithnames['appian'] = 'appianus-bio-1'
smithnames['arrian'] = 'arrianus-bio-2'
smithnames['baltic'] = 'suevicum-mare-geo'
smithnames['baltic sea'] = 'suevicum-mare-geo'
smithnames['barbyses'] = '-geo@https://pleiades.stoa.org/places/520970'
smithnames['basel'] = 'basilia-geo'
smithnames['batavia'] = 'batavi-geo'
smithnames['belgrade'] = 'singidunum-geo'
smithnames['bizon'] = 'bizone-geo'
smithnames['bonn'] = 'bonna-geo'
smithnames['britain'] = 'britannicae-insulae-geo'
smithnames['calvin'] = '-bio@https://en.wikipedia.org/wiki/John_Calvin'
smithnames['castabala'] = 'castabala-geo'
smithnames['catiline'] = 'catilina-l-sergius-bio-1'
smithnames['cassiodorius'] = 'cassiodorus-magnus-aurelius-bio-1'
smithnames['cevennes'] = 'cebenna-mons-geo'
smithnames['ceylon'] = 'taprobane-geo'
smithnames['china'] = 'sinae-geo'
smithnames['christ'] = '-bio@https://en.wikipedia.org/wiki/Jesus'
smithnames['chrysostom'] = 'chrysostomus-dion-bio-1'
smithnames['cimmerian bosphorus'] = 'bosporus-cimmerius-geo'

smithnames['cisalpine gaul'] = 'gallia-cisalpina-geo'
smithnames['corfu'] = 'corcyra-geo'
smithnames['cottian alpes'] = 'alpes-geo'

smithnames['danube'] = 'danubius-geo'
smithnames['dardanelles'] = 'hellespontus-geo'
smithnames['elbe'] = 'albis-geo'
smithnames['euxine'] = 'euxinus-pontus-geo'
smithnames['euclid'] = 'eucleides-bio-1'
smithnames['galen'] = 'galenus-claudius-bio-1'
smithnames['glykys'] = 'thyamis-geo'
smithnames['greece'] = 'graecia-geo'
smithnames['hadrianople'] = 'hadrianopolis-geo-1'
smithnames['hadriatic'] = 'adriaticum-mare-geo'
smithnames['horace'] = 'q-horatius-flaccus-bio-1'
smithnames['huns'] = 'hunni-geo'
smithnames['jesus'] = '-bio@https://en.wikipedia.org/wiki/Jesus'
#smithnames['julian'] = 'julianus-flavius-claudius-bio-1'
smithnames['julian alpes'] = 'alpes-geo'

smithnames['juvenal'] = 'juvenalis-decimus-junius-bio-1'
smithnames['langres'] = 'lingones-geo'
smithnames['livy'] = 'livius-bio-1'
smithnames['loire'] = 'liger-geo'
smithnames['lucan'] = 'lucanus-m-annaeus-bio-1'
smithnames['luther'] = '-bio@https://en.wikipedia.org/wiki/Martin_Luther'
smithnames['maximian herculius'] = 'herculius-maximianus-bio-1'
smithnames['mecca'] = 'macoraba-geo'
smithnames['mediterranean'] = 'mediterraneum-mare-geo'
smithnames['metz'] = 'divodurum-geo'
smithnames['meuse'] = 'mosa-geo02'
smithnames['mount athos'] = 'athos-geo'
smithnames['mount libanus'] = 'libanus-mons-geo'
smithnames['mount taurus'] = 'taurus-mons-geo'
smithnames['naples'] = 'neapolis-geo-1'
smithnames['nice'] = 'nicaea-geo-1'
smithnames['nineveh'] = 'ninus-geo'
smithnames['noricum'] = 'noricum-geo'
smithnames['ovid'] = 'p-ovidius-naso-bio-1'
smithnames['pagus tigurinus'] = 'tigurinus-pagus-geo'

smithnames['palestine'] = 'palaestina-geo'
smithnames['paris'] = 'lutetia-parisiorum-geo'
smithnames['peneus'] = 'peneius-geo'
smithnames['pennine alpes'] = 'alpes-geo'
smithnames['piraeus'] = 'piraeus-geo'

smithnames['philadelphia'] = 'philadelpheia-geo'

smithnames['pholoe'] = 'pholoe-geo'
smithnames['poitiers'] = 'limonum-geo'
smithnames['po'] = 'padus-geo'
smithnames['pyrenees'] = 'pyrenaei-montes-geo'
smithnames['rhaetian alpes'] = 'alpes-geo'

smithnames['rhine'] = 'rhenus-geo'
smithnames['rhone'] = 'rhodanus-geo'
smithnames['seine'] = 'sequana-geo'
smithnames['seville'] = 'hispalis-geo'
smithnames['siciliy'] = 'sicilia-geo'
smithnames['sozomen'] = 'sozomenus-hermeias-salamanes-bio-1'
smithnames['stobaeus'] = 'stobaeus-joannes-bio-1'
smithnames['taprobana'] = 'taprobane-geo'
smithnames['thames'] = 'tamesa-geo'
smithnames['thrace'] = 'thracia-geo'
smithnames['thracian bosphorus'] = 'bosporus-thracius-geo'
smithnames['tolouse'] = 'tolosa-geo'
smithnames['tours'] = 'caesarodunum-geo'
smithnames['transalpine gaul'] = 'gallia-transalpina-geo'
smithnames['treves'] = 'augusta-trevirorum-geo'
smithnames['tuscany'] = '-geo@https://en.wikipedia.org/wiki/Tuscany'
smithnames['vandals'] = 'vandali-geo'
smithnames['vistula'] = 'vistula-geo'
smithnames['volga'] = 'rha-geo'

f.close()


abbrevtable = {}
abbrevtable['Tillem.'] = 'pe,,Tillemont'
abbrevtable['Lactant.'] = 'pe,lactantius-bio-1,Lactantius'

oneturk = {}
multipleturks = {}
oneturkish = {}
rstype = {}

f = open('Place_and_ethnic.tsv')
for l in f:
    l = l.lower()
    l = re.sub('\s+$','',l)
    args = l.split('\t')
    #print(len(args),l)
    if(args[0] == 'place'):
        continue
    if(len(args) == 5):
        
        if( args[0]):
            curhead = args[0]
        else:
            curhead = args[3]
            
        curtype = args[1]
        
        oneturkf = args[2]
        oneturk[oneturkf] = curhead
        rstype[oneturkf] = curtype
        
        multipleturksf = args[3]
        #print(oneturkf,oneturk[oneturkf])
        multipleturks[multipleturksf] = curhead
        rstype[multipleturksf] = curtype
        
        oneturkishf = args[4]
        oneturkish[oneturkishf] = curhead
        rstype[oneturkishf] = curtype
        #print('list',oneturkf,multipleturksf,oneturkishf)

        
        #print(l)

f.close()


def get_place_and_ethnic(s):
    
    while(re.search('<name>([^<]+)</name>',s)):
        m = re.search('<name>([^<]+)</name>',s)
        if(m):
            lookkey = m[1].lower()
            #print('look',lookkey)
            #if(lookkey in oneturk):
                #print('oneturk',lookkey)
            if( lookkey in oneturk and lookkey in oneturkish):
                s = re.sub('<name>([^<]+)</name>','<rs type="'+rstype[lookkey]+':singpers+thing" n="'+ str(oneturkish[lookkey])+'">\g<1></rs>',s,1)
            elif( lookkey in oneturk ):
                s = re.sub('<name>([^<]+)</name>','<rs type="'+rstype[lookkey]+':singpers+not-thing" n="'+ str(oneturk[lookkey])+'">\g<1></rs>',s,1)
            elif( lookkey in oneturkish):
                s = re.sub('<name>([^<]+)</name>','<rs type="'+rstype[lookkey]+':not-singpers+thing" n="'+ str(oneturkish[lookkey])+'">\g<1></rs>',s,1)
            elif( lookkey in multipleturks):
                s = re.sub('<name>([^<]+)</name>','<rs type="'+rstype[lookkey]+':multipleturks" n="'+ str(multipleturks[lookkey])+'">\g<1></rs>',s,1)
            else:
                s = re.sub('(<name)(>[^<]+</name>)','\g<1>z\g<2>',s,1)
        else:
            s = re.sub('(<name)(>[^<]+</name>)','\g<1>z\g<2>',s,1)
    s = re.sub('<namez>','<name>',s)        
    return(s)

if('arabian' in oneturkish):
    print('hit on arabian')
else:
    print('fail on arabian')

l = 'the <name>Christian</name> person'
l = get_place_and_ethnic(l)
print(l)
# Out:
# 5 anaxo 1:00000433:anaxo-bio-1
# 5 c. apronius 1:0000387:apronius-bio-1
# 5 adule 1:00003876:adule-geo
# 5 bocchoris 1:00001477:bocchoris-bio-1
# 5 philonome 0.72:00000586:philonome-bio-1@0.27:00000224:philonome-bio-2
# 5 apameia 1:00012655:apameia-geo
# 5 laberius 0.77:00005121:laberius-decimus-bio-1@0.12:00000832:laberius-maximus-bio-1@0.07:00000466:q-laberius-durus-bio-1
# 5 aedon 1:00002485:aedon-bio-1
# 5 l. roscius fabatus 1:0008337:fabatus-l-roscius-bio-1
# 5 apollocrates 1:00000952:apollocrates-bio-1
# 5 l. statilius 0.68:0001096:statilius-bio-3@0.31:0000503:statilius-bio-5
# 5 theodore lascaris 1:0000452:lascaris-theodorus-bio-1
# 5 sidero 1:00000441:sidero-bio-1
# 5 nonnosus 1:00001307:nonnosus-bio-1
# 5 hylaea 1:00002010:hylaea-geo
# 5 limentinus 1:00000610:limentinus-bio-1
# 5 p. sextius 0.57:0002016:capitolinus-p-sextius-bio-1@0.21:0000766:sextius-bio-7@0.20:0000706:sextius-bio-5
# 5 m. junius siianus 1:0007125:silanus-junius-bio-6
# ...

# %%
import re

bury_places = {}
bury_people = {}
bury_ethnics = {}
bury_misc = {}

def addmisc(curtype,pers):
    pers = pers.lower()
    bury_misc[pers] = curtype

def addperson(pers):
    pers = pers.lower()
    if( pers in bury_people):
        bury_people[pers] = bury_people[pers] + 1
    else:
        bury_people[pers] = 1

def addplace(pers):
    pers = pers.lower()

    if( pers in bury_places):
        bury_places[pers] = bury_places[pers] + 1
    else:
        bury_places[pers] = 1

def addethnic(pers):
    pers = pers.lower()

    if( pers in bury_ethnics):
        bury_ethnics[pers] = bury_ethnics[pers] + 1
    else:
        bury_ethnics[pers] = 1


def buryindex():
    f = open('testout.tsv')

    for l in f:
        args = l.split('\t')
        rawhead = args[0]
        if(re.search('<rs[^>]',rawhead)):
        
            if( re.search('<rs[^<]+type="ethnic"',rawhead)):
                m = re.search('<rs[^<]+type="ethnic"[^>]*>([^<]+)',rawhead)
                addethnic(m[1])
            else:
                m = re.search('<rs[^>]+type="([^"]+)"[^>]*>([^<]+)',rawhead)
                if(m):
                    addmisc(m[1],m[2])
                else:
                    print('badrs',rawhead)

        curhead = re.sub('<[^>]+>','',rawhead)
        curclass = args[4]
        if(re.search(' ',curhead)):
            if(re.search('<persName',rawhead)):
                addperson(curhead)
            
        if(re.search('<placeName',rawhead)):
            addplace(curhead)

        m = re.search('<name type="nameLink">([^<]+)</name>\s+<surname>([^<]+)</surname>',rawhead)
        if(m):
            name = m[1] + ' ' + m[2]
            addperson(curhead)
        #print('namelink',name,curclass)
        
        m = re.search('\s+or\s+<[^>]+>([^<]+)',rawhead)
        if(m):
            name = m[1]
            if(re.search('<persName',rawhead)):
                addperson(curhead)
                print('or',name,curclass)

        m = re.search('<surname>([^<]+)</surname>',rawhead)
    
        if(m):
            name = m[1]
            addperson(name)
            if( re.search('[Dd]\'',name)):
                name2 = re.sub('[Dd]\'','',name)
                addperson(curhead)
            #print(name,name2,curclass)
        headargs = curhead.split()
    #print(curhead,headargs[0],args[4])
        basehead = headargs[0]
        if(re.search('^(Christian|Church|Egyptian|Forum|Golden|Greek|Grecian|Holy|Judicial|[Ii]mperial|Magister|Phoenician|Praetorian|Roman|Truce|Via)$',basehead)):
            continue
        if(re.search('simpname',l)):
            continue
        if(re.search('<persName',rawhead)):
            addperson(curhead)

        if(re.search('\-',basehead)):
            savehead = basehead
            basehead = re.sub('\-','',basehead)
            addperson(curhead)
            m = re.search('\-([A-Z][a-z]+)',savehead)
            if(m):
                curn = m[1]
                #print(curn,l)
                addperson(curhead)
        
    
    f.close()
    
buryindex()

def getburynames(s):
    while(re.search('<name>([^<]+)</name>',s)):
        m = re.search('<name>([^<]+)</name>',s)
        if(m):
            lookkey = m[1].lower()
            if( lookkey in bury_places):
                s = re.sub('<name>([^<]+)</name>','<placeName n="bury:'+ str(bury_places[lookkey])+'">\g<1></placeName>',s,1)
            elif( lookkey in bury_people):
                s = re.sub('<name>([^<]+)</name>','<persName n="bury:'+ str(bury_people[lookkey])+'">\g<1></persName>',s,1)
            elif( lookkey in bury_ethnics):
                s = re.sub('<name>([^<]+)</name>','<rs type="ethnic" n="bury:'+ str(bury_ethnics[lookkey])+'">\g<1></rs>',s,1)
            elif( lookkey in bury_misc):
                s = re.sub('<name>([^<]+)</name>','<rs type="'+ str(bury_misc[lookkey])+'" n="bury">\g<1></rs>',s,1)
            else:
                s = re.sub('(<name)(>[^<]+</name>)','\g<1>z\g<2>',s,1)
        else:
            s = re.sub('(<name)(>[^<]+</name>)','\g<1>z\g<2>',s,1)
    s = re.sub('<namez>','<name>',s)        
    return(s)

directions = {}

directions['Eastern'] = 'east'
directions['East'] = 'east'
directions['Western'] = 'west'
directions['West'] = 'west'
directions['Southern'] = 'south'
directions['South'] = 'south'
directions['Northern'] = 'northern'
directions['North'] = 'northern'
def getsingnames(s):
    
    s = re.sub('(Le) (Strange)','\g<1>-\g<2>',l)

    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+([A-Z]\.|[A-Z][a-z]+)\s+([A-Z]\.|[A-Z][a-z]+)\s+([A-Z]\.|[A-Z][a-z]+)\s+([A-Z][a-z\-]+|[Dd]\'[A-Z][a-z]+)','<persName><roleName n="\g<1>3">\g<1></roleName> <forename>\g<2></forename> <forename>\g<3></forename> <forename>\g<4></forename> <surname>\g<5></surname></persName>',s)

#Sir William Jones
    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+([A-Z]\.|[A-Z][a-z]+)\s+([A-Z][a-z\-]+|[Dd]\'[A-Z][a-z]+)','<persName><roleName n="\g<1>2">\g<1></roleName> <forename>\g<2></forename> <surname>\g<3></surname></persName>',s)

    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+([A-Z]\.|[A-Z][a-z]+|[Dd]\'[A-Z][a-z]+)','<persName><roleName n="\g<1>1">\g<1></roleName> <surname>\g<2></surname></persName>',s)
    
    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+([A-Z]\.|[A-Z][a-z]+)\s+([A-Z][a-z\-]+|[Dd]\'[A-Z][a-z]+)','<persName><roleName n="\g<1>1">\g<1></roleName> <forename>\g<2></forename> <surname>\g<3></surname></persName>',s)
    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+<name>([A-Z]\.|[A-Z][a-z]+)\s+([A-Z][a-z\-]+|[Dd]\'[A-Z][a-z]+)</name>','<persName><roleName n="\g<1>1a">\g<1></roleName> <forename>\g<2></forename> <surname>\g<3></surname></persName>',s)

    s = re.sub('(Mr\.|M\.|Dr\.|Sir)\s+<name>([A-Z]\.|[A-Z][a-z]+|[Dd]\'[A-Z][a-z]+)</namee>','<persName><roleName n="\g<1>1">\g<1></roleName> <surname>\g<2></surname></persName>',s)

    works = re.sub('<(surname|forename|addName|genName|placeName|name|roleName|title|bibl)[^>]*>[^<]+',' ',s)

    works = re.sub('<[^>]+>',' ',works)
    works = re.sub("'s\b'"," s",works)
    works = re.sub('[\.;:!,"\)\()\]\[]',' ',works)
    words = works.split()
    sawwords = {}
    for foo in words:
        foo = re.sub("('s|\')$",'',foo)

        if( re.search('^[0-9]',foo) or foo in sawwords):
            continue
            
        if( not re.search('^([A-Z][a-z\-]+|[Dd]\'[A-Z][a-z\-]+)$',foo)):
            continue

        if(foo.lower() in smithnames):
            skeys = smithnames[foo.lower()]
            skeylist = skeys.split('@')
            if( re.search('-bio',skeylist[0])):
                tmpid = re.sub('^-(bio)@','',foo.lower())
                t1 = '<persName n="' + smithnames[tmpid] + '">'
                t2 = '</persName>'
            elif( re.search('-geo',skeylist[0])):
                tmpid = re.sub('^-(geo)@','',foo.lower())
                t1 = '<placeName n="' + smithnames[tmpid] + '">'
                t2 = '</placeName>'

            else:
                t1 = '<name n="' + smithnames[foo.lower()] + '">'
                t2 = '</name>'
            s = re.sub('\\b'+foo+'\\b',t1 + foo + t2,s)
            #print(foo)
        elif( foo in directions):
            t1 = '<rs type="direction" n="' + directions[foo] + '">'
            t2 = '</rs>'
            s = re.sub(foo+'\\b',t1 + foo + t2,s)
        elif( not foo.lower() in lcasewords):
            s = re.sub('\\b'+foo+'\\b','<name>' + foo + '</name>',s)
            
        sawwords[foo] = 1
    s = re.sub('(Le)\-(Strange)','\g<1> \g<2>',s)
    s = re.sub('(<title n="[^"]*)<[^>]+>([^"]+)<[^>]+>','\g<1>\g<2>',s)
    while(re.search('( n="[^"]*)<[^>]+>',s)):
        s = re.sub('( n="[^"]*)<[^>]+>','\g<1>',s)
    #s = re.sub('(<title[^>]+>[^<]*)<name>([^[<]+)</name>','\g<1>\g<2>',s)
    return(s)

l = "While the West state was exhausted by the Persian war, and the church was distracted by the Nestorian and Monophysite sects, "
getsingnames(l)
# Out:
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# 'While the <rs type="direction" n="west">West</rs> state was exhausted by the <name>Persian</name> war, and the church was distracted by the <name>Nestorian</name> and <name>Monophysite</name> sects, '

# %%
import re

romvalues = {}
romvalues['I']  = 1
romvalues['II']  = 2
romvalues['III']  = 3
romvalues['IV']  = 4
romvalues['V']  = 5
romvalues['VI']  = 6
romvalues['VII']  = 7
romvalues['VIII']  = 8
romvalues['IX']  = 9
romvalues['X']  = 10
romvalues['XI']  = 11
romvalues['XII']  = 12
romvalues['XIII']  = 13
romvalues['XIV']  = 14
romvalues['XV']  = 15
romvalues['XVI']  = 16
romvalues['XVII']  = 17
romvalues['XVIII']  = 18
romvalues['XIX']  = 19
romvalues['XX']  = 20
romvalues['XXI']  = 21
romvalues['XXII']  = 22
romvalues['XXIII']  = 23
romvalues['XXIV']  = 24
romvalues['XXV']  = 25
romvalues['XXVI']  = 26
romvalues['XXVII']  = 27
romvalues['XXVIII']  = 28
romvalues['XXIX']  = 29
romvalues['XXX']  = 30
romvalues['XXXI']  = 31
romvalues['XXXII']  = 32
romvalues['XXXIII']  = 33
romvalues['XXXIIV']  = 34
romvalues['XXXV']  = 35
romvalues['XXXVI']  = 36
romvalues['XXXVII']  = 37
romvalues['XXXVIII']  = 38
romvalues['XXXIX']  = 39
romvalues['XL']  = 40
romvalues['L']  = 50

suetworks = {}
suetworks['Caesar.'] = 'urn:cts:latinLit:phi1348.abo011'
suetworks['Aug.'] = 'urn:cts:latinLit:phi1348.abo012'
suetworks['August.'] = 'urn:cts:latinLit:phi1348.abo012'
suetworks['Tiber.'] = 'urn:cts:latinLit:phi1348.abo013'
suetworks['Tiberio.'] = 'urn:cts:latinLit:phi1348.abo013'
suetworks['Claud.'] = 'urn:cts:latinLit:phi1348.abo015'
suetworks['Neron.'] = 'urn:cts:latinLit:phi1348.abo016'
suetworks['Galb.'] = 'urn:cts:latinLit:phi1348.abo017'
suetworks['Galba.'] = 'urn:cts:latinLit:phi1348.abo017'
suetworks['Vitell.'] = 'urn:cts:latinLit:phi1348.abo019'
suetworks['Vespasian.'] = 'urn:cts:latinLit:phi1348.abo020'
suetworks['Tit.'] = 'urn:cts:latinLit:phi1348.abo021'
suetworks['Domit.'] = 'urn:cts:latinLit:phi1348.abo022'
suetworks['Domitian.'] = 'urn:cts:latinLit:phi1348.abo022'

tacworks = {}
tacworks['Annal.'] = 'urn:cts:latinLit:phi1351.phi003'
tacworks['Hist.'] = 'urn:cts:latinLit:phi1351.phi004'
def getcancit(s):
    m = re.search('(Persic\.)\s+(l\.)\s+(i|ii)\.\s+(c\.)\s([0-9]+)',s)
    if(m):
        author = "Procopius"
        works = m[1]
        books = m[3]
        bookn = str(romvalues[books.upper()])
        chapn = m[5]
        s = re.sub('(Persic\.)\s+(l\.)\s+(i|ii)\.\s+(c\.)\s([0-9]+)','<bibl n="'+author+', \g<1> '+bookn + '.\g<5>">\g<1> \g<2> \g<3> \g<4> \g<5></bibl>',s)

        
    if(re.search('(Germania|German\.|De Moribus Germ\.|Germ\.)([, ]+|[,\s]+c\.\s+)([0-9]|[0-9][0-9])\\b',s)):
        #print('germania',s)
        s = re.sub('(Germania|German\.|De Moribus Germ\.|Germ\.)([, ]+|[,\s]+c\.\s+)([0-9]|[0-9][0-9])\\b','<bibl n="urn:cts:latinLit:phi1351.phi002:\g<3>">\g<1>\g<2>\g<3></bibl>',s)

    if(re.search('(Vit\.\s+Agricol\.|Agricola)([, ]+|[,\s]+c\.\s+)([0-9]|[0-9][0-9])\\b',s)):
        #print('germania',s)
        s = re.sub('(Vit\.\s+Agricol\.)([, ]+|[,\s]+c\.\s+)([0-9]|[0-9][0-9])\\b','<bibl n="urn:cts:latinLit:phi1351.phi001:\g<3>">\g<1>\g<2>\g<3></bibl>',s)

    #deal with an exception
    s = re.sub('(Tacit\.) (vi\. 44)','\g<1> <bibl n="urn:cts:latinLit:phi1351.phi003:6.44">\g<2></bibl>',s)
    m = re.search('(Annal\.|Hist\.)\s+([ivxl]+)(\.\s+|\.\s+c\.\s+)([0-9\-]+)',s)  
    if(m):
        cururn = tacworks[m[1]]
        books = m[2]
        bookn = str(romvalues[books.upper()])
        s = re.sub('(Annal\.|Hist\.)\s+([ivxl]+)(\.\s+|\.\s+c\.\s+)([0-9\-]+)','<bibl n="'+cururn + ':'+bookn+'.\g<4>">\g<1> \g<2>\g<3>\g<4></bibl>',s)
    
    s = re.sub('(Tacit\.)','<persName n="tacitus-c-cornelius-bio-1">\g<1></persName>',s)
    
    m = re.search('(Ammian\.|Ammianus|Ammian)(\s+Marcellin\.|\s+Marcellinus|)(\s+|,\s+l\.\s+)([ivxl]+)(\.\s+|\.\s+c\.\s+)([0-9\-]+)',s)  
    if(m):
        cururn = 'urn:cts:latinLit:stoa0023.stoa001'
        books = m[4]
        bookn = str(romvalues[books.upper()])
        s = re.sub('(Ammian\.|Ammianus)(\s+Marcellin\.|\s+Marcellinus|)(\s+|,\s+l\.\s+|,\s+)([ivxl]+)(\.\s+|\.\s+c\.\s+)([0-9\-]+)','<persName n="ammianus-marcellinus-bio-1">\g<1><y/>\g<2></persName>\g<3><bibl n="'+cururn + ':'+bookn+'.\g<6>">\g<4>\g<5>\g<6></bibl>',s)
        s = re.sub(' (l\.\s+)(<bibl[^>]*>)',' \g<2>\g<1>',s)

    m = re.search('(Suet\.|Sueton\.|Suetonius)\s+in\s+([A-Z][a-z]+[\.*])([,\s]+c\.\s+)([0-9\-]+)',s)
    if(m):
        cururn = suetworks[m[2]]
        s = re.sub('(Suet\.|Sueton\.|Suetonius)(\s+in\s+)([A-Z][a-z]+[\.*])([,\s]+c\.\s+)([0-9\-]+)','<bibl n="'+cururn+':\g<5>">\g<1>\g<2>\g<3>\g<4>\g<5></bibl>',s)
        #print('suet:',m[1],m[2],m[4])
    return(s)

authorlist ={}
authorlist['Ammian.'] = 'Ammianus,ammianus-marcellinus-bio-1,urn:cts:latinLit:stoa0023'
authorlist['Ammianus'] = 'Ammianus,ammianus-marcellinus-bio-1,urn:cts:latinLit:stoa0023'
authorlist['Dion'] = 'Dio,dion-cassius-cocceianus-bio-1,urn:cts:greekLit:tlg0385'
authorlist['Dionys. Halicarn.'] = 'Dionysius of Halicarnassus,dionysius-bio-29,urn:cts:greekLit:tlg0081'
authorlist['Dionys. Hal.'] = 'Dionysius of Halicarnassus,dionysius-bio-29,urn:cts:greekLit:tlg0081'


authorlist['Evagrius'] = 'Evagrius,evagrius-bio-3,urn:cts:greekLit:tlg2733'
authorlist['Eusebius'] = 'Eusebius,eusebius-bio-1,urn:cts:greekLit:tlg2018'
authorlist['Euseb.'] = 'Eusebius,eusebius-bio-1,urn:cts:greekLit:tlg2018'
authorlist['Herod.'] = 'Herodotus,herodotus-bio-1,urn:cts:greekLit:tlg0016'
authorlist['Herodotus'] = 'Herodotus,herodotus-bio-1,urn:cts:greekLit:tlg0016'
authorlist['Livy'] = 'Livy,livius-bio-1,urn:cts:latinLit:phi0914'
authorlist['Pausanias'] = 'Pausanias,pausanias-bio-11,urn:cts:greekLit:tlg0525'
authorlist['Socrates'] = 'Socrates Scholasticus,socrates-bio-8,urn:cts:greekLit:tlg2057'
authorlist['Socrates'] = 'Socrates Scholasticus,socrates-bio-8,urn:cts:greekLit:tlg2057'
authorlist['Thucydid.'] = 'Thucydides,thucydides-bio-1,urn:cts:greekLit:tlg0003'
authorlist['Thuc.'] = 'Thucydides,thucydides-bio-1,urn:cts:greekLit:tlg0003'
authorlist['Thucydides'] = 'Thucydides,thucydides-bio-1,urn:cts:greekLit:tlg0003'
authorlist['Veget.'] = 'Vegetius,vegetius-flavius-renatus-bio-1,urn:cts:latinLit:stoa0287'
authorlist['Vegetius'] = 'Vegetius,vegetius-flavius-renatus-bio-1,urn:cts:latinLit:stoa0287'

worklist = {}
worklist['Hist. Ecclesiast.'] = 'Historia Ecclesiastica'
worklist['Hist. Eccles.'] = 'Historia Ecclesiastica'
worklist['Hist. Eccl.'] = 'Historia Ecclesiastica'

uniqueworklist = {}
uniqueworklist['de bel. peloponn.'] = 'de Bello Peloponnesiaco,urn:cts:greekLit:tlg0003.tlg001'
uniqueworklist['de m. p.'] = 'De Mortibus Persecutorum,urn:cts:latinLit:stoa0171.stoa002'
uniqueworklist['de mortibus persecutorum'] = 'De Mortibus Persecutorum,urn:cts:latinLit:stoa0171.stoa002'

uniqueworklist['de re militari'] = 'De Re Militari,urn:cts:latinLit:stoa0287.stoa001'

authorworklist = {}
authorworklist['urn:cts:greekLit:tlg2018 Historia Ecclesiastica'] = 'tlg017'
authorworklist['urn:cts:greekLit:tlg2733 Historia Ecclesiastica'] = 'tlg001'
authorworklist['urn:cts:greekLit:tlg2057 Historia Ecclesiastica'] = 'tlg001'


defaultauthorwork = {}
defaultauthorwork['urn:cts:greekLit:tlg0003'] = 'tlg001'
defaultauthorwork['urn:cts:greekLit:tlg0016'] = 'tlg001'
defaultauthorwork['urn:cts:greekLit:tlg0081'] = 'tlg001'

defaultauthorwork['urn:cts:greekLit:tlg0385'] = 'tlg001'
defaultauthorwork['urn:cts:greekLit:tlg0525'] = 'tlg001'

defaultauthorwork['urn:cts:greekLit:tlg2057'] = 'tlg001'
defaultauthorwork['urn:cts:greekLit:tlg2733'] = 'tlg001'

defaultauthorwork['urn:cts:latinLit:phi0914'] = 'phi001'

defaultauthorwork['urn:cts:latinLit:stoa0023'] = 'stoa001'
defaultauthorwork['urn:cts:latinLit:stoa0287'] = 'stoa001'

titlelist = {}


def author_book_chapter(s):
    while( re.search('([A-Z][a-z]+[\.]*|[A-Z][a-z\.]+\s+[A-Z][a-z\.]+)([,\s\(]+)<ref type="(rnum-anum|book-chapter|chapter)" n="([^"]+)">([^<]+)</ref>',s)):
        m = re.search('([A-Z][a-z]+[\.]*|[A-Z][a-z\.]+\s+[A-Z][a-z\.]+)([,\s\(]+)<ref type="(rnum-anum|book-chapter|chapter)" n="([^"]+)">([^<]+)</ref>',s)
        if(m):
            curword = m[1]
            if(curword in authorlist):
                authorinfo = authorlist[curword].split(',')
            #print('curw',curword,authorinfo[2])

                if(authorinfo[2] in defaultauthorwork):
                    authorworkid = authorinfo[2] + ':' + defaultauthorwork[authorinfo[2]]
                #print('authorwork',authorworkid,curword)
                    s = re.sub('([A-Z][a-z]+[\.]*|[A-Z][a-z\.]+\s+[A-Z][a-z\.]+)([,\s\(]+)<ref type="(rnum-anum|book-chapter|chapter)" n="([^"]+)">([^<]+)</ref>','<persName n="'+authorinfo[1] +'">\g<1></persName>\g<2><bibl n="'+authorworkid+':\g<4>">\g<5></bibl>',s,1)
                else:
                    s = re.sub('([A-Z][a-z]+[\.]*|[A-Z][a-z\.]+\s+[A-Z][a-z\.]+)([,\s\(]+)(<ref type="(rnum-anum|book-chapter|chapter)" n="([^"]+)">([^<]+)</ref>)','\g<1><g/>\g<2>\g<3>',s,1)

            else:
                s = re.sub('([A-Z][a-z]+[\.]*|[A-Z][a-z\.]+\s+[A-Z][a-z\.]+)([,\s\(]+)(<ref type="(rnum-anum|book-chapter|chapter)" n="([^"]+)">([^<]+)</ref>)','\g<1><g/>\g<2>\g<3>',s,1)

    s = re.sub('<g/>','',s)    
    while(re.search('([A-Z][a-z]+[\.]*)([,\s\(]+)([A-Z][a-z]+[\.]*\s+[A-Z][a-z]+[\.]*)',s)):

        m = re.search('([A-Z][a-z]+[\.]*)([,\s\(]+)([A-Z][a-z]+[\.]*\s+[A-Z][a-z]+[\.]*)',s)
        if(m):
            curauth = m[1]
            curwork = m[3]
            if(curauth in authorlist and curwork in worklist):
                authorinfo = authorlist[curauth].split(',')
                authorid = authorinfo[1]
                authorcts = authorinfo[2]
                workname=worklist[curwork]
                curkey = authorcts + ' ' + workname
            #print(curauth,authorlist[curauth],curwork,worklist[curwork],curkey)
                if(curkey in authorworklist):
                #print('curkey',authorworklist[curkey])
                    ctswork = authorworklist[curkey]
                    s = re.sub('([A-Z][a-z]+[\.]*)([,\s\(]+)([A-Z][a-z]+[\.]*\s+[A-Z][a-z]+[\.]*)','<persName n="'+authorid+'">\g<1></persName>\g<2><bibl n="'+authorcts+'.'+ctswork+'">\g<3></bibl>',s,1)
                else:
                    s = re.sub('([A-Z][a-z]+[\.]*)([,\s\(]+)([A-Z][a-z]+[\.]*\s+[A-Z][a-z]+[\.]*)','\g<1><g/>\g<2>\g<3>',s,1)
            else:
                s = re.sub('([A-Z][a-z]+[\.]*)([,\s\(]+)([A-Z][a-z]+[\.]*\s+[A-Z][a-z]+[\.]*)','\g<1><g/>\g<2>\g<3>',s,1)
    s = re.sub('<g/>','',s)    

    m = re.search('([A-Z][a-z]+[\.]*)([,\s\(]+<ref type="book-page" n=")([0-9]+\.)([0-9\-]+">[^<]+</ref>[, ]+\[)([0-9]+)',s)
    if(m):
        curword = m[1]
        curbook = m[3]
        curchap = m[5]
        if(curword in authorlist):
            authorinfo = authorlist[curword].split(',')
            if(authorinfo[2] in defaultauthorwork):
                cururn = authorinfo[2] + '.' + defaultauthorwork[authorinfo[2]] + ':' + curbook + curchap
                #print(curword,curbook,curchap,cururn,s)
                s = re.sub('([A-Z][a-z]+[\.]*)([,\s\(]+<ref type="book-page" n=")([0-9]+\.)([0-9\-]+">[^<]+</ref>[, ]+\[)([0-9]+)','<persName n="'+authorinfo[1]+'">\g<1></persName>\g<2>\g<3>\g<4><bibl n="'+cururn+'">\g<5></bibl>',s)

    s = re.sub('(<bibl n="[^"]+)(">[^<]+)(</bibl>)([,\s]+)<ref type="(book-chapter|rnum-anum|chapter)" n="([^"]+)">([^<]+)</ref>','\g<1>:\g<6>\g<2>\g<4>\g<7>\g<3>',s)        
# kludgey exceptions

    s = re.sub('(Thucydides) (de Bel\. Peloponn\.)\s+<ref type="book-chapter" n="([^"]+)">([^<]+)</ref>','<persName n="thucydides-bio-1">\g<1></persName> <bibl n="urn:cts:greekLit.tlg0003:tlg001:\g<3>">\g<2> \g<4></bibl>',s)
    return(s)
def gettitles(s):
    s = re.sub('(Jewish\s+and\s+Heathen|Heathen|)\s+(Testimonies)','<title n="Jewish and Heathen Testimonies">\g<1> \g<2></title>',s)
    s = re.sub('(Hist\.\s+des)\s+(Emp\.|Empereurs|Emper\.)','<title n="Histoire des Empereurs">\g<1> \g<2></title>',s)
    s = re.sub('(Hist\.\s+des)\s+(Allemands)','<title n="Histoire des Allemands">\g<1> \g<2></title>',s)
    s = re.sub('(Hist\.|Histoire)\s+(des\s+Peuples)([,\.])','<title n="Histoire des Peuples de l\'Europe">\g<1>\g<2></title>\g<3>',s)
    s = re.sub('(Hist\.|Histoire)(\s+des|\s+Générale\s+des)\s+(Huns|Mongous|Juifs|Sacremens|Peuples\s+de\s+l\'Europe),','<title n="Histoire Générale des \g<3>">\g<1>\g<2> \g<3></title>,',s)
    s = re.sub('(Hist\.|Histoire)\s+(Générale des Voyages|des Voyages)','<title n="Histoire Générale des Voyages">\g<1> \g<2></title>',s)
    s = re.sub("(Hist\.|Histoire)(\s+des\s+[gG]rands\s+)(Chemins\s+des\s+Romains|Chemins\s+de\s+l'Empire\s+Romain|Chemins)",'<title n="Histoire des grands Chemins de l\'Empire Romain">\g<1>\g<2>\g<3></title>',s)
    s = re.sub("(Hist\.)\s+(August\.|Aug\.)",'<title n="Historia Augusta">\g<1> \g<2></title>',s)
    s = re.sub("(Hist\.\s+Ecclés\.)",'<title n="Historia Ecclésiastique">\g<1></title>',s)
    s = re.sub("(Hist\.\s+des Musulmans d'Espagne)",'<title n="Histoire des Musulmans d\'Espagne">\g<1></title>',s)
    s = re.sub("(Hist\.\s+de\s+l'Afrique\s+et\s+de\s+l'Espagne\s+sous\s+la\s+Domination\s+des\s+Arabes,|Hist\.\s+de\s+l'Afrique\s+et\s+de\s+l'Espagne\s+sous\s+les\s+Arabes,|Hist\.\s+de\s+l'Afrique\s+et\s+de\s+l'Espagne,)",'<title n="Histoire de l\'Afrique et de l\'Espagne sous la Domination des Arabes">\g<1></title>',s)
    s = re.sub("(Hist\.)\s+(du Commerce des Anciens),",'<title n="Histoire \g<2>">\g<1> \g<2></title>,',s)
    s = re.sub('(Hist\.)\s+(of\s+[^,]+),','<title n="History \g<2>">\g<1> \g<2></title>',s)
    s = re.sub("(Hist\.)\s+(de\s+l'Esclavage)",'<title n="Histoire \g<2>">\g<1> \g<2></title>',s)
    
    s = re.sub('(Hist\.)\s+(de\s+C\.\s+P\.)','<title n="Histoire3 \g<2>">\g<1> <z/>\g<2></title>',s)
    s = re.sub('(Hist\.)\s+(du|de)(\s+[^\]<,]+),','<title n="Histoire2 \g<2>\g<3>">\g<1> \g<2>\g<3></title>',s)
    s = re.sub('(Histoire|Hist\.)\s+(des Celtes)','<title n="Histoire \g<2>">\g<1> \g<2></title>',s)
    s = re.sub('(Istoria)\s+(Civile\s+di\s+Napoli|di\s+Napoli|Civile),','<title n="Istoria Civili di Napoli">\g<1> \g<2></title>',s)
    s = re.sub('(Pignorius) (de Servis)','<persName>\g<1></persName> <title n="https://www.worldcat.org/title/-de-servis-et-eorum-apud-veteres-ministerijs-commentarius/oclc/1203399056">\g<2></title>',s)
    s = re.sub("(Essai sur l'Histoire|Hist\.|Histoire)\s+(Générale)([,\.])","<title n=\"Essai sur l'Histoire Générale\">\g<1> \g<2></title>\g<3>",s)
    s = re.sub("(Canisii\s+Antiq\.\s+Lectiones)",'<title n="https://catalog.hathitrust.org/Record/012314638">\g<1></title>',s)
    s = re.sub("(Mémoires|Mém\.)( de l')(Académie\\b|Acad\.)(\s+des\s+Inscriptions|)",'<title n="Mémoires de l\'Académie des Inscriptions">\g<1>\g<2>\g<3>\g<4></title>',s)
    s = re.sub('(Specimen\sHist\.\s+Arab\.|Specimen\s+Hist\.\s+Arabicae|Specimen\s+Historiae\s+Arabum|Specimen)','<title n="Specimen Historiae arabum">\g<1></title>',s)
    s = re.sub('(Hist\.|Histoire)\s+(des Variations des Eglises Protestantes)','<title n="Histoire des Variations des Eglises Protestantes">\g<1> \g<2></title>',s)
    s = re.sub('(Hist\.|Historia)\s+(Saracen.|Saracenica)','<title n="Historia Saracenica">\g<1> \g<2></title>',s)
    s = re.sub('(Hist\.|Historia)\s+(Arabum)','<title n="Historia Arabum">\g<1> \g<2></title>',s)

    s = re.sub('(Hist\.|Historia)\s+(Hierosolymitana|Hierosol\.|Hierosolym\.)','<title n="Historia Hierosolymitana">\g<1> \g<2></title>',s)
    
    
    s = re.sub('<z/>','',s)

    while(re.search('(\\bl\.\s+|\\blib\.\s+|\\b)([ivxl]+)\.\s+v\.\s+([0-9\-]+)',s)):
        m = re.search('(\\bl\.\s+|\\blib\.\s+|\\b)([ivxl]+)\.\s+v\.\s+([0-9\-]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            anum = m[3]
            s = re.sub('(\\bl\.\s+|\\blib\.\s+|\\b)([ivxl]+)(\.\s+v\.)\s+([0-9\-]+)','<ref type="book-line" n="'+rnum+'.'+ anum+'">\g<1><b/>\g<2>\g<3> <b/>\g<4></ref>',s,1)

    while(re.search('(\\bl\.|\\blib\.)\s+([ivxl]+)\.\s+p\.\s+([0-9\-]+)',s)):
        m = re.search('(\\bl\.|\\blib\.)\s+([ivxl]+)\.\s+p\.\s+([0-9\-]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            anum = m[3]
            s = re.sub('(\\bl\.\s+|\\blib\.)([ivxl]+)\.\s+p\.\s+([0-9\-]+)','<ref type="book-page" n="'+rnum+'.'+ anum+'">\g<1><b/>\g<2>. p. <b/>\g<3></ref>',s,1)

    while(re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+p\.\s+([0-9\-]+)',s)):
        m = re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+p\.\s+([0-9\-]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            anum = m[3]
            s = re.sub('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+p\.\s+([0-9\-]+)','<ref type="volume-page" n="'+rnum+'.'+ anum+'">\g<1> <b/>\g<2>. p. <b/>\g<3></ref>',s,1)

    while(re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+c\.\s+([0-9\-]+)',s)):
        m = re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+c\.\s+([0-9\-]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            anum = m[3]
            s = re.sub('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.\s+c\.\s+([0-9\-]+)','<ref type="volume-chapter" n="'+rnum+'.'+ anum+'">\g<1> <b/>\g<2>. c. <b/>\g<3></ref>',s,1)

    while(re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.',s)):
        m = re.search('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            s = re.sub('(\\btom\.|\\bvol\.)\s+([ivxl]+)\.','<ref type="volume" n="'+rnum+'">\g<1> <b/>\g<2>.</ref>',s,1)

    while(re.search('(\\bl\.|\\blib\.)\s+([ivxl]+)\.(\s+c\.\s+|\s+)([0-9\-]+)',s)):
        m = re.search('(\\bl\.|\\blib\.)\s+([ivxl]+)\.(\s+c\.\s+|\s+)([0-9\-]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))        
            anum = m[4]
            s = re.sub('(\\bl\.|\\blib\.)\s+([ivxl]+)\.(\s+c\.\s+|\s+)([0-9\-]+)','<ref type="book-chapter" n="'+rnum+'.'+ anum+'">\g<1> <b/>\g<2>.\g<3><b/>\g<4></ref>',s,1)

    while(re.search('(\\bp\.)\s+([0-9\-]+)',s)):
        m = re.search('(\\bp\.)\s+([0-9\-]+)',s)
        if(m):
            s = re.sub('(\\bp\.)\s+([0-9\-]+)','<ref type="page" n="\g<2>">\g<1> <b/>\g<2></ref>',s,1)

    while(re.search('(\\bc\.)\s+([ivxl]+)',s)):
        m = re.search('(\\bc\.)\s+([ivxl]+)',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper())) 
            s = re.sub('(\\bc\.)\s+([ivxl]+)','<ref type="chapter" n="'+rnum+'">\g<1> <b/>\g<2></ref>',s,1)
        
    while(re.search('(\\bc\.)\s+([0-9\-]+)',s)):
        m = re.search('(\\bc\.)\s+([0-9\-]+)',s)
        if(m):
            s = re.sub('(\\bc\.)\s+([0-9\-]+)','<ref type="chapter" n="\g<2>">\g<1> <b/>\g<2></ref>',s,1)
        
    while(re.search('\\b([ivxl]+)\.(\s*)([0-9][0-9\-]*)',s)):
        m = re.search('\\b([ivxl]+)\.(\s*)([0-9][0-9\-]*)',s)
        if(m):
            rnum = str(romanToDecimal(m[1].upper()))        
            anum = m[3]
            s = re.sub('\\b([ivxl]+)\.(\s*)([0-9][0-9\-]*)','<ref type="rnum-anum" n="'+rnum+'.'+ anum+'">\g<1>.<b/>\g<3></ref>',s,1)

    while(1 and re.search('(\\bl\.\s+|\\blib\.\s+)([ivxl]+)\.',s)):
        m = re.search('(\\bl\.\s+|\\blib\.\s+)([ivxl]+)\.',s)
        if(m):
            rnum = str(romanToDecimal(m[2].upper()))
            s = re.sub('(\\bl\.\s+|\\blib\.\s+)([ivxl]+)\.','<ref type="book" n="'+rnum+'">\g<1><b/>\g<2>.</ref>',s,1)

    s = re.sub('<b/>','',s)
    
    if(re.search('\\b([dD]e)\s+([A-Z][a-z\.]+\s+[A-Z][a-z\.]+)',s)):
        m = re.search('\\b([dD]e)\s+([A-Z][a-z\.]+\s+[A-Z][a-z\.]+)',s)
        if(m and m[1].lower()+' '+m[2].lower() in uniqueworklist):
            curinfo = uniqueworklist[m[1].lower()+' '+m[2].lower()]
            curid = curinfo.split(',')[1]
            s = re.sub('\\b([dD]e)\s+([A-Z][a-z\.]+\s+[A-Z][a-z\.]+)','<bibl n="'+curid+'">\g<1><z/> \g<2></bibl>',s,1)
            #print('unique',m[1],m[2],curid)
        else:
            s = re.sub('\\b([dD]e)\s+([A-Z][a-z\.]+\s+[A-Z][a-z\.]+)','\g<1><z/> \g<2>',s,1)

    s = re.sub('<z/>','',s)
    s = author_book_chapter(s)
    s = re.sub('(Pliny|Plin\.)(\s+\(|\s+in\s+|\s+)(Panegyr\.)\s+<ref type="chapter" n="([0-9\.]+)">([^<]+)</ref>','<persName n="c-plinius-caecilius-secundus-bio-1">\g<1></persName>\g<2><bibl n="urn:cts:latinLit:phi1318.phi002:\g<4>">\g<3> \g<5></bibl>',s)

    s = re.sub('(Plin\.|Pliny)([\(\s]+)(Hist\.\s+Nat\.|Hist\.\s+Natur\.)\s+<ref type="rnum-anum" n="([0-9\.]+)">([^<]+)</ref>','<persName n="c-plinius-secundus-bio-1">\g<1></persName>\g<2><bibl n="urn:cts:latinLit:phi0978.phi001:\g<4>">\g<3> \g<5></bibl>',s)
    s = re.sub(' (Hist\.|Histoire)\s+(Naturelle|Natur\.)',' <title n="Histoire Naturelle">\g<1> \g<2></title>',s)

    s = re.sub('(\\b[Dd]e\s+M\.\s+P\.)\s+<ref type="chapter" n="([0-9\.]+)">([^<]+)</ref>','<bibl n="urn:cts:latinLit:stoa0171.stoa002:\g<2>">\g<1> \g<3></bibl>',s)

    #s = re.sub('(Pomponius\s+Mela)([\.\s]+)<ref type="book-chapter" n="([0-9\.\-]+)">([^<]+)</ref>','<persName n="mela-pomponius-bio-1">\g<1></persName>\g<2><bibl n="urn:cts:latinLit:phi0929.phi001:\g<3>">\g<4></bibl>',s)
    s = re.sub('(Vegetius)([\.,\s]+)<ref type="rnum-anum" n="([0-9\.\-]+)">([^<]+)</ref>','<persName n="vegetius-flavius-renatus-bio-1">\g<1></persName>\g<2><bibl n="urn:cts:latinLit:stoa0287.stoa001:\g<3>">\g<4></bibl>',s)

    while(re.search('(<ref type="[^"]+" n="[0-9]+\.)([0-9]+">[^<]+</ref>,\s+)([0-9]+)',s)):
        m = re.search('(<ref type="[^"]+" n="[0-9]+\.)([0-9]+">[^<]+</ref>,\s+)([0-9]+)',s)
        if(m):
            s = re.sub('(<ref type="[^"]+" n="[0-9]+\.)([0-9]+">[^<]+</ref>,\s+)([0-9]+)','\g<1>\g<2>\g<1>\g<3>">\g<3></ref>',s,1)

    while(re.search('(<ref type="[^"]+" n=")([0-9]+">[^<]+</ref>,\s+)([0-9]+)',s)):
        m = re.search('(<ref type="[^"]+" n=")([0-9]+">[^<]+</ref>,\s+)([0-9]+)',s)
        if(m):
            s = re.sub('(<ref type="[^"]+" n=")([0-9]+">[^<]+</ref>,\s+)([0-9]+)','\g<1>\g<2>\g<1>\g<3>">\g<3></ref>',s,1)
    works = re.sub('<(title|bibl)[^>]+>[^<]+','',s)
    m = re.search('(Hist\.|Histoire)([^,<"]+)',works)
    if(m):
        curname = m[1] + m[2]
        if(curname in titlelist):
            titlelist[curname] = titlelist[curname] + 1
        else:
            titlelist[curname] = 1
    return(s)

l = "Tacit. in Vit. Agricol. c. 15); or, as t"
getcancit(l)
foo=gettitles('See Lactant. de M. P. c. 38.')
print(foo)
# Out:
# See Lactant. <bibl n="urn:cts:latinLit:stoa0171.stoa002:38">de M. P. c. 38</bibl>.

# %%
import re 

names = {}
persnames = {}
placenames = {}
ethnics = {}

def countnames(s):
    curtot = 0
    perstot = 0
    placetot = 0
    ethnictot = 0
    saves = s
    while(re.search('<name>([^<]+)',s)):
        curtot = curtot + 1
        m = re.search('<name>([^<]+)',s)
        curn = m[1]
        if( curn in names):
            names[curn] = 1 + names[curn]
        else:
            names[curn] = 1
        s = re.sub('<name>[^<]+','',s,1)
    
    s = saves
    while(re.search('<persName[^>]*>([^<]+)',s)):
        perstot = perstot + 1
        m = re.search('<persName[^>]*>([^<]+)',s)
        curn = m[1]
        if( curn in persnames):
            persnames[curn] = 1 + persnames[curn]
        else:
            persnames[curn] = 1
        s = re.sub('<persName[^>]*>[^<]+','',s,1)
       
    
    s = saves
    while(re.search('<placeName[^>]*>([^<]+)',s)):
        placetot = placetot + 1
        m = re.search('<placeName[^>]*>([^<]+)',s)
        curn = m[1]
        if( curn in placenames):
            placenames[curn] = 1 + placenames[curn]
        else:
            placenames[curn] = 1
        s = re.sub('<placeName[^>]*>[^<]+','',s,1)
       
    
    s = saves
    while(re.search('<rs[^>]+type="ethnic[^>]*>([^<]+)',s)):
        ethnictot = ethnictot + 1
        m = re.search('<rs[^>]+type="ethnic[^>]*>([^<]+)',s)
        curn = m[1]
        if( curn in ethnics):
            ethnics[curn] = 1 + ethnics[curn]
        else:
            ethnics[curn] = 1
        s = re.sub('<rs[^>]+type="ethnic[^>]*>([^<]+)','',s,1)
       
    return(curtot,perstot,placetot,ethnictot)


f = open('bury-all.xml')
outf = open('bury-all-pn.xml','w')

binames = {}

ordinals = {}
ordinals['First'] = 1
ordinals['Second'] = 2
ordinals['Third'] = 3
ordinals['Fourth'] = 4
ordinals['Fifth'] = 5
ordinals['Sixth'] = 6
ordinals['Seventh'] = 7
ordinals['Eighth'] = 8
ordinals['Ninth'] = 9
ordinals['Tenth'] = 10
ordinals['Eleventh'] = 11
ordinals['Twelfth'] = 12
ordinals['Thirteenth'] = 13
ordinals['Fourteenth'] = 14
ordinals['Fourteenth'] = 15

ordpat = '('
for foo in ordinals:
    if( ordpat == '('):
        ordpat = ordpat + foo
    else:
        ordpat = ordpat + '|' + foo

ordpat = ordpat + ')'
print('ordpat',ordpat)

i = 0
romannums = '[IVXL]+'


prevval = 0
intext = 0
gennames = 0

ucstopwords = {}
ucstopwords['Add'] = 1
ucstopwords['Although'] = 1
ucstopwords['At'] = 1
ucstopwords['But'] = 1
ucstopwords['Called'] = 1
ucstopwords['Compare'] = 1
ucstopwords['Even'] = 1
ucstopwords['For'] = 1
ucstopwords['In'] = 1
ucstopwords['If'] = 1
ucstopwords['See'] = 1
ucstopwords['So'] = 1
ucstopwords['The'] = 1
ucstopwords['These'] = 1
ucstopwords['This'] = 1
ucstopwords['Those'] = 1
ucstopwords['Thus'] = 1
ucstopwords['When'] = 1
ucstopwords['Whenever'] = 1
ucstopwords['While'] = 1

forenames = '(John|Paul)'

totnames = 0
totpersnames = 0
totplacenames = 0
totethnics = 0

wordpat = '[A-Z][a-zçèéāâ]+'
for l in f:
    if( 0 and not re.search('id="ch[0-9]+\.pa[0-9]+"',l)):
        print(l,end='',file=outf)
        continue
    if(re.search('<text>',l)):
        intext = 1
        
    if(not intext):
        print(l,end='',file=outf)
        continue
    l = getcancit(l)
    l = gettitles(l)

    l = re.sub('([Tt]he)\s+(Save)\\b','\g<1> <placeName type="river">\g<2></placeName>',l)
    l = re.sub('(St\.)\s+(' + wordpat + ')','<persName><addName n="Saint">\g<1></addName> <surname>\g<2></surname></persName>',l)
    while(re.search('(' + wordpat + ')\s+('+romannums+')\.',l)):
        m = re.search('(' + wordpat + ')\s+('+romannums+')\.',l)
        cap = m[1]
        cname = m[2]
        if(cname in romvalues):
            romnum = str(romvalues[cname])
        else:
            romnum = 'tba'
            print('novalue',cap,cname)
        if( cap.lower() in lcasewords):
            l = re.sub('('+wordpat+')\s+('+romannums+')\.','\g<1><z/> \g<2>.',l,1)
            print(l[0:20],'skip',cap)
            continue
        l = re.sub('(' + wordpat + ')\s+('+romannums+')\.','<persName><surname>\g<1></surname> <genName n="'+romnum +'">\g<2>.</genName></persName>',l,1)

    while(re.search('(' + wordpat + ')(\s+the\s+)'+ordpat+'\\b',l)):
        m = re.search('(' + wordpat + ')(\s+the\s+)'+ordpat+'\\b',l)
        cap = m[1]
        cname = m[3]
        gennames = gennames+ 1
        curgen = str(ordinals[cname])
        #print(gennames,cap+' the '+cname)
        l = re.sub('(' + wordpat + ')\s+(the\s+)'+ordpat+'\\b','<persName><surname>\g<1></surname> <genName n="'+ curgen + '">\g<2>\g<3></genName></persName>',l,1)

    l = re.sub('<z/>','',l)
    while(re.search('(romannums)(\.\s+)([A-Z][a-zç\']+|<hi|A\s|<q|<pb)',l)):
        m = re.search('(romannums)(\.\s+)([A-Z][a-zç\']+|<hi|A\s|<q|<pb)',l)
        if(m):
            cap = m[3]
            rnum = m[1]
            curval = rnum
            if( re.search('^'+romannums+'$',rnum)):
                if( not rnum in romvalues):
                    print('novalue',end='\t')
                #print('roman',l[0:20],end='\t')
                curval = romvalues[rnum]
                if( curval == 1):
                    prevval = 0
                if( 0 and not curval == prevval+ 1):
                    print('jump from',prevval,curval,l,end='')
                prevval = curval

                l = re.sub('(romannums)(\.\s+)([A-Z][a-zç\']+|<hi|A\s|<q|<pb)','<num value="'+ str(romvalues[rnum])+'">\g<1></num>\g<2>\g<3>',l,1)
            else:
                l = re.sub('(romannums)(\.\s+)([A-Z][a-zç\']+|<hi|A\s|<q|<pb)','\g<1><z/>\g<2>\g<3>',l,1)
                print('unroman',cap,rnum)
            
            #print(m[1]+m[2]+m[3])
    l = re.sub('<z/>','',l)
    
    while(re.search('('+wordpat+')\s+('+wordpat+')',l)):
        m = re.search('('+wordpat+')\s+('+wordpat+')',l)
        if(m):
            word1 = m[1]
            word2 = m[2]
            if (word1.lower() in excepts and excepts[word1.lower()] == rolename):
                    rs1 = '<persName><roleName>'
                    rs2 = '</roleName> <surname>'
                    rs3 = '</surname></persName>'
                    l = re.sub(word1 + '\s+' + word2,rs1+word1 + rs2 + word2 + rs3,l)
            elif(  word1.lower() in lcasewords):
                if( word1 in ucstopwords or lcasewords[word1.lower()]>  100):
                    rs1 = ''
                    rs2 = ' <z/>'
                    rs3 = ''
                else:
                    #rs1 = '<rs n="'  + str(lcasewords[word1.lower()])+'">'
                    rs1 = ''
                    rs2 = ' <z/>'
                    #rs3 = '</rs>'
                    rs3 = ''
                l = re.sub(word1 + '\s+' + word2,rs1+word1 + rs2 + word2 + rs3,l)
            else:
                compname = word1 + ' ' + word2
                lccomp = compname.lower()
                if( lccomp in smithnames):
                    nkeys = smithnames[lccomp]
                    nkeylist = nkeys.split('@')
                    if( re.search('-bio',nkeylist[0])):
                        l = re.sub(word1 + '\s+' + word2,'<persName n="' +nkeys+ '"><forename>'+ word1 + '</forename> <surname>'+ word2 + '</surname></persName>',l)
                    elif(re.search('-geo',nkeylist[0])):
                        l = re.sub(word1 + '\s+' + word2,'<placeName n="' +nkeys+ '">' + word1 + ' <z/>' + word2+'</placeName>',l)
                else:
                    l = re.sub(word1 + '\s+' + word2,'<name>' + word1 + ' <z/>' + word2+'</name>',l)

                if( compname in binames):
                    binames[compname] = binames[compname] + 1
                else:
                    binames[compname] = 1
                    
            #print(l[0:25],'compname?',word1,word2)
    l = re.sub('<z/>','',l)

    l = re.sub('(<bibl n="[^"]+)<name>([^"]+)</name>','\g<1>\g<2>',l)
    l = re.sub('(<title n="[^"]+)<name>([^"]+)</name>','\g<1>\g<2>',l)
    l = re.sub('(<name>)<name>([^<]+)</name>','\g<1>\g<2>',l)

    l = re.sub("([Dd]\')<name>",'<name>d\'',l)
    l = re.sub('</name>\s+(di\s+|sur\s+l\'|sur\s+|de[s]*\s+|sur\s+le[s]*\s+|zwischen\s+|und\s+)<name>',' \g<1>',l)
    l = re.sub('\\b(d\'\s*|l\'\s*|d[eu]\s+|des\s+)(<name>)','\g<2>\g<1>',l)

    l = getsingnames(l)

    l = getburynames(l)

    l = get_place_and_ethnic(l)
    
    l = re.sub('<name>(Mont|Mount)\s+([^<]+)</name>','<placeName n="montpat" type="mountain">\g<1> \g<2></placeName>',l)
    l = re.sub('<name>(Recherches|Histoire)([^<]*)</name>(\s+sur\s+|\s+du\s+)([^,<]+)','<title xml:lang="fra">\g<1>\g<2>\g<3>\g<4></title>',l)
    l = re.sub('</name>([\.\s]+)<name>','\g<1>',l)
    l = re.sub('<addName n="Saint"><name>St</name>','<addName n="Saint">St',l)
    
    l = re.sub('<name>'+forenames+'</name>\s+(of)\s+<name>([^<]+)</name>','<persName n="fore1"><forename>\g<1></forename> \g<2> <placeName>\g<3></placeName></persName>',l)
    l = re.sub('<name>'+forenames+'</name>\s+(of)\s+(<placeName[^>]*>[^<]+</placeName>)','<persName n="fore2"><forename>\g<1></forename> \g<2> \g<3></persName>',l)
    
    l = re.sub('(<surname>)<name>([^<]+)</name>(</surname>)','\g<1>\g<2>\g<3>',l)
    
    l = re.sub('<name><name>'+forenames+'</name>\s+('+wordpat+')</name>','<persName n="nn"><forename>\g<1></forename> <surname>\g<2></surname></persName>',l)
    l = re.sub('<name><name>'+forenames+'\s+([A-Z][^<]+</name>)','<persName><forename>\g<1></forename> <surname>\g<2></surname></persName>',l)

    l = re.sub('<name>(Pope|Emperor)</name>\s+(<persName[^>]*>)','\g<2><roleName>\g<1></roleName> ',l)
    l = re.sub('([Tt]he|[Aa])\s+<name>(Pope|Emperor)</name>','\g<1> <roleName>\g<2></roleName>',l)
    
    l = re.sub('(<title[^>]+>)<name>([^<]+)</name>','\g<1>\g<2>',l)
    l = re.sub('<y/>','',l)
#    l = re.sub('\[([^\]]+)\]','<note resp="bury">\g<1></note>',l)
    
    l = re.sub('<name><name>(Mount)</name>\s+([^ <]+)</name>','<geogName type="mountain">\g<1> \g<2></geogName>',l)
    l = re.sub('(<surname>)<persName[^>]+>([^<]+)</persName>','\g<1>\g<2>',l)
    l = re.sub('(M\.)\s+(de)\s+<persName([^>]*)>([^<]+)</persName>','<persName n="M-de"><roleName>\g<1></roleName> <name type="nameLink">\g<2></name> <surname\g<3>>\g<4></surname></persName>',l)
    while(re.search('(<persName[^>]*>[^<]*)(<name>|</name>)',l)):
        l = re.sub('(<persName[^>]*>[^<]*)(<name>|</name>)','\g<1>',l)
    l = re.sub('(<persName[^>]*>)<persName[^>]*>([^<]+)</persName>(</persName>)','\g<1>\g<2>\g<3>',l)
    counts = countnames(l)
    totnames = counts[0] + totnames
    totpersnames = counts[1] + totpersnames
    totplacenames = counts[2] + totplacenames
    totethnics = counts[3] + totplacenames
    print(l,end='',file=outf)

f.close()
outf.close()
print('donescan')
# Out:
# ordpat (First|Second|Third|Fourth|Fifth|Sixth|Seventh|Eighth|Ninth|Tenth|Eleventh|Twelfth|Thirteenth|Fourteenth)
# <note xml:id="ch43n1 skip See
# <note xml:id="ch47n7 skip Mark
# <note xml:id="ch58n4 skip Victor
#
# titlelist
# 29 Hist. Eccles.
# 28 Hist.
# 15 Hist. Critique
# 14 Hist. Patriarch. Alex.
# 10 Hist. Armen.
# 10 Hist. Sacra
# 9 Hist. Critique du Manichéisme
# 8 Hist. Natur.
# 8 Hist. Orient.
# 7 Histoire de l'Afrique et de l'Espagne sous la Domination des Arabes
# 7 Hist. C. P.
# 6 Hist. Hispan.
# 6 Hist. Ecclésiastique
# 6 Hist. Miscell.
# 6 Hist. Ducum
# 5 Hist. Ecclesiast.
# 5 Hist. Lausiac.
# 5 Hist. Review
# 5 Hist. Major
# 4 Hist. Philosoph.
#
# people
# 972 Constantine
# 811 Julian
# 624 Justinian
# 448 Theodosius
# 430 Mahomet
# 373 Procopius
# 366 Augustus
# 360 Constantius
# 350 Christ
# 350 Zosimus
# 311 Caesar
# 306 Muratori
# 291 Tillemont
# 277 Belisarius
# 266 Gregory
# 262 Diocletian
# 226 Ammianus
# 218 Theodoric
# 214 Ducange
# 207 John
#
# places
# ...

# %%
print("<name/>",totnames,'<persName/>',totpersnames,'<placeName/>',totplacenames,'<rs type="ethnic">',totethnics)

maxshow = 30
print('\ntitlelist')
i = 0
for foo in sorted(titlelist,key=titlelist.get,reverse=True):
    foolc = foo.lower()
    i = i + 1
    if(i > maxshow):
        continue
    print(titlelist[foo],foo)

print('\npeople')
i = 0
for foo in sorted(persnames,key=persnames.get,reverse=True):
    foolc = foo.lower()
    i = i + 1
    if(i > maxshow):
        continue
    print(persnames[foo],foo)

i = 0
print('\nplaces')
for foo in sorted(placenames,key=placenames.get,reverse=True):
    foolc = foo.lower()
    i = i + 1
    if(i > maxshow):
        continue
    print(placenames[foo],foo)



i = 0
print('\nethnics')
for foo in sorted(ethnics,key=ethnics.get,reverse=True):
    foolc = foo.lower()
    i = i + 1
    if(i > maxshow):
        continue
    print(ethnics[foo],foo)


print('\nunclassified capitalized words')
i = 0
for foo in sorted(names,key=names.get,reverse=True):
    foolc = foo.lower()
    i = i + 1
    if(i > 300):
        continue
    print(names[foo],foo)
# Out:
# <name/> 31467 <persName/> 37726 <placeName/> 26116 <rs type="ethnic"> 26116
#
# titlelist
# 29 Hist. Eccles.
# 28 Hist.
# 15 Hist. Critique
# 14 Hist. Patriarch. Alex.
# 10 Hist. Armen.
# 10 Hist. Sacra
# 9 Hist. Critique du Manichéisme
# 8 Hist. Natur.
# 8 Hist. Orient.
# 7 Histoire de l'Afrique et de l'Espagne sous la Domination des Arabes
# 7 Hist. C. P.
# 6 Hist. Hispan.
# 6 Hist. Ecclésiastique
# 6 Hist. Miscell.
# 6 Hist. Ducum
# 5 Hist. Ecclesiast.
# 5 Hist. Lausiac.
# 5 Hist. Review
# 5 Hist. Major
# 4 Hist. Philosoph.
# 4 Hist. Nat.
# 4 Hist. Goth.
# 4 Hist. Crit. Philosoph.
# 4 Hist. Patriarch. Alexandrin.
# 4 Hist. Dynast.
# 3 Hist. Var.
# 3 Histoire de Timur Bec
# 3 Hist. Naturelle
# 3 Histoire des Empereurs
# 3 Hist. Arcan.
#
# people
# 972 Constantine
# 811 Julian
# 624 Justinian
# 448 Theodosius
# 430 Mahomet
# 373 Procopius
# 366 Augustus
# 360 Constantius
# 350 Christ
# 350 Zosimus
# 311 Caesar
# 306 Muratori
# 291 Tillemont
# 277 Belisarius
# 266 Gregory
# ...

# %%
buryindex()
for foo in sorted(names,key=names.get,reverse=True):
    if( foo in bury_people):
        print('person',bury_people[foo],foo,names[foo])
    elif(foo in bury_ethnics):
        print('ethnic',bury_ethnics[foo],foo,names[foo])
    elif(foo in bury_places):
        print('bury_places',bury_places[foo],foo,names[foo])
    elif(foo in bury_misc):
        print('bury_misc',bury_misc[foo],foo,names[foo])
    else:
        print('failed',foo,names[foo])
# Out:
# or Restan persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# or Zarathustra persName
# failed Appendix 356
# failed Christ 336
# failed Orat 196
# failed Hist 184
# failed Caesars 151
# failed Koran 151
# failed Gibbon 131
# failed Vatican 127
# failed Chron 124
# failed England 113
# failed Migne 96
# failed Godefroy 95
# failed Vit 92
# failed Annal 66
# failed Russia 66
# failed Gregorovius 66
# failed Travels 63
# failed Theod 59
# failed Bibliothèque Orientale 58
# failed Mommsen 57
# failed Histoire 56
# failed Father 56
# failed Panegyr. Vet 56
# failed Gesch 55
# failed Concil 55
# failed Theodosian Code 54
# failed Annal. Eccles 54
# failed Caled 53
# failed Euseb 51
# failed Jesus 50
# failed Count 50
# failed King 49
# failed Augustan History 49
# failed Opp 49
# failed Abbassides 48
# failed Bibliot 47
# failed Bibliot. Orient 47
# ...

# %%
import re
nextwords = {}

f = open('bury-all-pn.xml')
for l in f:
    while(re.search('Hist</name>\.\s+([^,]+),',l)):
        m = re.search('Hist</name>\.\s+([^,]+),',l)
        if(m):
            curw = m[1]
            if(curw in nextwords):
                nextwords[curw] = nextwords[curw]+1
            else:
                nextwords[curw] = 1
        l =  re.sub('Hist</name>\.\s+([^,]+),',' ',l,1)
f.close()

for foo in sorted(nextwords,key=nextwords.get,reverse=True):
    print(nextwords[foo],foo)
# Out:
# 10 Sacra
# 7 Générale
# 6 des <name>Peuples</name>
# 6 Review
# 5 des <name>Allemands</name>
# 4 Ecclésiastique
# 4 <placeName n="0.81:00003157:syrtis-major-geo@0.18:00000701:petras-major-geo">Major</placeName>
# 3 des Huns</title>
# 2 August
# 2 des Variations <name>des Eglises Protestantes</name>
# 2 des Juifs</title>
# 2 Geography of <placeName n="bury:14">Asia Minor</placeName>
# 2 Générale des <placeName n="hunni-geo">Huns</placeName>
# 2 Généalogique des <rs type="ethnic:multipleturks" n="tartary">Tartars</rs>
# 2 des <name>Chevaliers</name> de <name>Malthe</name>
# 2 C. P. c. 8
# 1 l. xxxiv. and xxxvi. <persName n="0.31:00005961:florus-annaeus-bio-1@0.20:00003777:florus-gessius-bio-1@0.17:00003281:florus-annaeus-bio-2@0.07:00001477:florus-julius-bio-1@0.07:00001367:florus-l-aquillius-bio-1@0.05:00001104:florus-c-aquillius-bio-1@0.02:00000558:florus-julius-secundus-bio-1">Florus</persName>
# 1 Arcanâ
# 1 des grands Chemins</title>
# 1 iii. 36
# ...

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame([
    dict(Task="Augustus", Start='1737-05-08', Finish='1794-01-16', Author="Gibbon"),
    dict(Task="Augustus", Start='1711-05-11', Finish='1776-08-26', Author="Hume"),
    dict(Task="Augustus", Start='1721-09-11', Finish='1793-06-11', Author="Robertson"),
    #dict(Task="Tiberius", Start='0014', Finish='0037', Resource="Alex"),
    #dict(Task="Caligula", Start='0037', Finish='0041', Resource="Max")
])

fig = px.timeline(df, x_start="Start", x_end="Finish", y="Author", color="Author")
fig.show()
# Out:
# <div>                            <div id="e502efbe-d680-46ee-9c5d-a8adb7a85f7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e502efbe-d680-46ee-9c5d-a8adb7a85f7d")) {                    Plotly.newPlot(                        "e502efbe-d680-46ee-9c5d-a8adb7a85f7d",                        [{"alignmentgroup":"True","base":["1737-05-08"],"hovertemplate":"Author=%{y}<br>Start=%{base}<br>Finish=%{x}<extra></extra>","legendgroup":"Gibbon","marker":{"color":"#636efa"},"name":"Gibbon","offsetgroup":"Gibbon","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[1789084800000.0],"xaxis":"x","y":["Gibbon"],"yaxis":"y"},{"alignmentgroup":"True","base":["1711-05-11"],"hovertemplate":"Author=%{y}<br>Start=%{base}<br>Finish=%{x}<extra></ext
# ...

# %%
import plotly.express as px
import pandas as pd
df = px.data.iris()

f = open('bury-all.xml')


datelist = []
volpagelist = []
for l in f:
    if(re.search('<note xml:id="ch([0-9]+)n([0-9]+)"',l)):
        m = re.search('<note xml:id="ch([0-9]+)n([0-9]+)"',l)
        curchap = int(m[1])
        curnote = int(m[2])
        volpage = 1000*curchap + curnote
    while(re.search('<date when="([0-9\-][0-9]+)"',l)):
        m = re.search('<date when="([0-9\-][0-9]+)"',l)
        #curdate = re.sub('^[0]+','',m[1])
        curdate = int(m[1])
        l = re.sub('<date when="([0-9\-]+)"',' ',l,1)
        #avoid the outlier 
        # The Great Pyramid of Gizeh was the tomb of Khufu (Cheops), the second king of the 4th dynasty said to have flourished in <date when="-3969">B.C. 3969</date>-3908.
        if(int(curdate) > -1000):
            volpagelist.append(volpage)
            datelist.append(int(curdate))

f.close()


fig = px.scatter(df, x=volpagelist, y=datelist)
fig.show()
# Out:
# <div>                            <div id="0ae53cad-175c-4e17-a6b9-90371e370ea0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ae53cad-175c-4e17-a6b9-90371e370ea0")) {                    Plotly.newPlot(                        "0ae53cad-175c-4e17-a6b9-90371e370ea0",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergl","x":[1009,1020,1023,1028,1033,1076,2001,2001,2015,2022,3001,3001,4007,4010,4047,5072,6010,6037,6043,6120,7060,7064,7072,7072,8009,8042,8049,10042,10088,10097,10118,11034,13011,13043,13091,14035,14073,14104,14106,14107,15111,15158,15163,16031,16031,16044,16044,16058,16109,16123,16123,161
# ...

# %%
df
# Out:
#       Page    Date
# 0     1009    85.0
# 1     1020   114.0
# 2     1023   117.0
# 3     1028   161.0
# 4     1076     9.0
# ..     ...     ...
# 924  67038  1464.0
# 925  67042  1466.0
# 926  67042  1431.0
# 927  67049  1461.0
# 928  67053  1445.0
#
# [929 rows x 2 columns]

# %%
# x and y given as array_like objects
import plotly.express as px
#fig = px.scatter(x=[47126, 47129, 47132, 47138, 47138], y=[833, 513, 578, 676, 14])
fig = px.scatter(x=volpagelist, y=datelist)
fig.show()
# Out:
# <div>                            <div id="a6daa2f5-536d-4bdb-b250-f0e79a5b39c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6daa2f5-536d-4bdb-b250-f0e79a5b39c5")) {                    Plotly.newPlot(                        "a6daa2f5-536d-4bdb-b250-f0e79a5b39c5",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[1009,1020,1023,1028,1076,4007,4010,4047,5072,6010,6037,6043,6120,7060,7064,7072,7072,8009,8042,8049,10042,10088,10097,10118,11034,13011,13043,13091,14035,14073,14104,14106,14107,15111,15158,15163,16031,16031,16044,16044,16058,16109,16123,16123,16132,16170,16178,1706
# ...

# %%
f = open('bury-all-pn.xml')

adds = {}

for l in f:
    m = re.search('</name>\s+of\s+('+wordpat+')',l)
    if(m):
        print(m[1])

f.close()
# Out:
# Kings
# Kings
# Kings
# Heaven
# Olives
# Neo
# God
# Ancient
# Olives
# Quadrupeds
# Ancient
# Fr
# Orthodoxy
# Demosthenes
# Bokh
# Chauffepi
# Ancient
# Commons

# %%
import re

def updatefile(fname):
    f = open(fname + '.xml')
    outf = open(fname + '-work.xml','w')
    inbody = 0
    prevpage = 0
    prevvol = 0
    for l in f:
        if(re.search('<body>',l)):
            inbody = 1
        if(not inbody):
            print(l,end='',file=outf)
            continue
            
        if( re.search('<(note|fig)',l)):
            print(l,end='',file=outf)
            continue
        
        workl = l
        while(re.search('<pb n="v([0-9][0-9])p([0-9][0-9][0-9])',workl)):
            m = re.search('<pb n="v([0-9][0-9])p([0-9][0-9][0-9])',workl)
            if(m):
                curvol = int(m[1])
                curpage = int(m[2])
                if(not curvol == prevvol):
                    if(curvol == prevvol + 1):
                        prevpage = 0
                    elif(  not curvol == prevvol + 11):
                        print('jump vols',prevvol,curvol,l)
                if( not curpage == prevpage + 1):
                    print('jumppage',curvol,prevpage,curpage)
                prevvol = curvol
                prevpage = curpage
            workl = re.sub('<pb n="v([0-9][0-9])p([0-9][0-9][0-9])',' ',workl,1)
        l = re.sub('\\b([IVXL0-9]+\.|St\.|Dr\.|Mr\.|[A-Z]\.)\s+','\g<1>---',l)

        #l = re.sub('\s*(<pb[^>]+>|<p [^>]+>)','\n\g<1>\n',l)
        l = re.sub('([\.!?]|[\.!?]</quote>|[\.!?]</hi>)(\s+|<ref[^>]+>\s+|\s*<pb[^>]+>\s*)([A-Z]|<quote)','\g<1>\g<2>\n\n\g<3>',l)
        l = re.sub('(<p [^>]+>)','\g<1>\n',l)
        l = re.sub('(</p>)','\n\g<1>',l)
        l = re.sub('---',' ',l)

        print(l,end='',file=outf)

    f.close()
    outf.close()
    
    outf = open(fname + '-out.xml','w')
    f = open(fname + '-work.xml')

    inbody = 0
    curpage = ''
    for l in f:
        if(re.search('<body>',l)):
            inbody = 1
        if(not inbody):
            print(l,end='',file=outf)
            continue
        l = re.sub('(id="ch)([0-9][0-9])\.','\g<1>\g<2>',l)
        l = re.sub('(id="ch)([0-9])\.','\g<1>0\g<2>',l)
        l = re.sub('(pa)([0-9])"','\g<1>0\g<2>"',l)
        m = re.search('<p xml:id="(ch[0-9]+pa[0-9]+)"',l)
        if(m):
            curparid = m[1]
            sentnum = 1
            
        l = re.sub('(<p [^>]+pa)([0-9]+)"','\g<1>\g<2>" n="\g<2>"',l)
        l = re.sub(' n="[0]*',' n="',l)
        l = re.sub('\[([^\]]+)\]','<note resp="bury">\g<1></note>',l)
        if(re.search('^<(div|list|head|fig|note|item|l\\b|date)',l)):
            print(l,end='',file=outf)
            continue
        workl = re.sub('<[^>]+>','',l)
        if(workl[0].isupper()):
            sentnums = str(sentnum)
            sentnums = re.sub('^([0-9]$)','00\g<1>',sentnums)
            sentnums = re.sub('^([0-9][0-9]$)','0\g<1>',sentnums)
            sentid = curparid + 'se' + sentnums
            print('<s xml:id="'+sentid+'" n="' + str(sentnum)+'"/>',file=outf,end='')
            sentnum = sentnum + 1
        
        print(l,file=outf,end='')
        
    f.close()
    outf.close()

#updatefile('bury-all')
#print('done')
